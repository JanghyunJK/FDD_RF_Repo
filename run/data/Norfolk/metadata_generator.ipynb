# %%
import os
import pandas as pd

# %%
file_list = os.listdir(os.getcwd()+"/Norfolk")
meta_data_file = [x for x in file_list if '_metadata' in x][0]
data_file_list = [x for x in file_list if '_metadata' not in x]
print(meta_data_file)
print(data_file_list)
# Out:
# Norfolk_metadata.csv
# ['air_handling_unit_fan_motor_degradation_doas_0.1.csv', 'air_handling_unit_fan_motor_degradation_doas_0.2.csv', 'air_handling_unit_fan_motor_degradation_doas_0.3.csv', 'air_handling_unit_fan_motor_degradation_doas_0.4.csv', 'air_handling_unit_fan_motor_degradation_doas_1_0.1.csv', 'air_handling_unit_fan_motor_degradation_doas_1_0.2.csv', 'air_handling_unit_fan_motor_degradation_doas_1_0.3.csv', 'air_handling_unit_fan_motor_degradation_doas_1_0.4.csv', 'baseline.csv', 'condenser_fouling_chiller_0.4.csv', 'excessive_infiltration_0.4.csv', 'hvac_setback_error_delayed_onset_3.0.csv', 'hvac_setback_error_no_overnight_setback_All_days.csv', 'hvac_setback_error_no_overnight_setback_Weekdays_only.csv', 'hvac_setback_error_no_overnight_setback_Weekend_only.csv', 'improperly_sized_equipment_wshp_1.5.csv', 'lighting_setback_error_early_termination_3.0.csv', 'nonstandard_charging_chiller_1.4.csv', 'presence_of_noncondensable_chiller_0.04.csv', 'supply_air_duct_leakages_0.3.csv', 'thermostat_bias_3.0.csv']

# %%
meta_data = pd.DataFrame([])

for data_file in data_file_list:

    sensor_filename = os.path.splitext(data_file)[0]
    print(sensor_filename)

    if '_' in sensor_filename:
        if 'All_days' in sensor_filename:
            fault_type = sensor_filename[0:-9]
            fault_intensity = 'All_days'
            print('1')
        elif 'Weekdays_only' in sensor_filename:
            fault_type = sensor_filename[0:-14]
            fault_intensity = 'Weekdays_only'
            print('2')
        elif 'Weekend_only' in sensor_filename:
            fault_type = sensor_filename[0:-13]
            fault_intensity = 'Weekend_only'
            print('3')
        else:
            fault_type, fault_intensity = sensor_filename.rsplit('_', 1)
            print('4')
    else:
        fault_type = sensor_filename
        fault_intensity = '0'
        print('5')

    meta = {'sensor_filename': [sensor_filename],
            'fault_type': [fault_type],
            'fault_intensity': [fault_intensity]}
    meta_df = pd.DataFrame.from_dict(meta)
    meta_data = pd.concat([meta_data, meta_df], axis = 0)
    

meta_data
# Out:
# air_handling_unit_fan_motor_degradation_doas_0.1
# 4
# air_handling_unit_fan_motor_degradation_doas_0.2
# 4
# air_handling_unit_fan_motor_degradation_doas_0.3
# 4
# air_handling_unit_fan_motor_degradation_doas_0.4
# 4
# air_handling_unit_fan_motor_degradation_doas_1_0.1
# 4
# air_handling_unit_fan_motor_degradation_doas_1_0.2
# 4
# air_handling_unit_fan_motor_degradation_doas_1_0.3
# 4
# air_handling_unit_fan_motor_degradation_doas_1_0.4
# 4
# baseline
# 5
# condenser_fouling_chiller_0.4
# 4
# excessive_infiltration_0.4
# 4
# hvac_setback_error_delayed_onset_3.0
# 4
# hvac_setback_error_no_overnight_setback_All_days
# 1
# hvac_setback_error_no_overnight_setback_Weekdays_only
# 2
# hvac_setback_error_no_overnight_setback_Weekend_only
# 3
# improperly_sized_equipment_wshp_1.5
# 4
# lighting_setback_error_early_termination_3.0
# 4
# nonstandard_charging_chiller_1.4
# 4
# presence_of_noncondensable_chiller_0.04
# 4
# supply_air_duct_leakages_0.3
# 4
# thermostat_bias_3.0
# 4
#                                      sensor_filename  \
# 0   air_handling_unit_fan_motor_degradation_doas_0.1
# 0   air_handling_unit_fan_motor_degradation_doas_0.2
# 0   air_handling_unit_fan_motor_degradation_doas_0.3
# 0   air_handling_unit_fan_motor_degradation_doas_0.4
# 0  air_handling_unit_fan_motor_degradation_doas_1...
# 0  air_handling_unit_fan_motor_degradation_doas_1...
# 0  air_handling_unit_fan_motor_degradation_doas_1...
# 0  air_handling_unit_fan_motor_degradation_doas_1...
# 0                                           baseline
# 0                      condenser_fouling_chiller_0.4
# 0                         excessive_infiltration_0.4
# 0               hvac_setback_error_delayed_onset_3.0
# 0   hvac_setback_error_no_overnight_setback_All_days
# 0  hvac_setback_error_no_overnight_setback_Weekda...
# 0  hvac_setback_error_no_overnight_setback_Weeken...
# 0                improperly_sized_equipment_wshp_1.5
# 0       lighting_setback_error_early_termination_3.0
# 0                   nonstandard_charging_chiller_1.4
# 0            presence_of_noncondensable_chiller_0.04
# 0                       supply_air_duct_leakages_0.3
# 0                                thermostat_bias_3.0
#
#                                        fault_type fault_intensity
# 0    air_handling_unit_fan_motor_degradation_doas             0.1
# 0    air_handling_unit_fan_motor_degradation_doas             0.2
# 0    air_handling_unit_fan_motor_degradation_doas             0.3
# 0    air_handling_unit_fan_motor_degradation_doas             0.4
# 0  air_handling_unit_fan_motor_degradation_doas_1             0.1
# 0  air_handling_unit_fan_motor_degradation_doas_1             0.2
# 0  air_handling_unit_fan_motor_degradation_doas_1             0.3
# 0  air_handling_unit_fan_motor_degradation_doas_1             0.4
# 0                                        baseline               0
# 0                       condenser_fouling_chiller             0.4
# 0                          excessive_infiltration             0.4
# 0                hvac_setback_error_delayed_onset             3.0
# 0         hvac_setback_error_no_overnight_setback        All_days
# 0         hvac_setback_error_no_overnight_setback   Weekdays_only
# 0         hvac_setback_error_no_overnight_setback    Weekend_only
# 0                 improperly_sized_equipment_wshp             1.5
# 0        lighting_setback_error_early_termination             3.0
# 0                    nonstandard_charging_chiller             1.4
# 0              presence_of_noncondensable_chiller            0.04
# 0                        supply_air_duct_leakages             0.3
# 0                                 thermostat_bias             3.0

# %%
meta_data.to_csv(meta_data_file)
