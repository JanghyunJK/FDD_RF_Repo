# %%
import pandas as pd
import glob
import os
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
file1 = "../data/Norfolk/Norfolk/summary_results_algorithm_Norfolk_AMY.csv"
df_meta = pd.read_csv(file1)
df_meta

aggregate_n_runs = 6*24 # number of datapoints 
reporting_datapoints = int(365 * (6*24)/aggregate_n_runs) # number of datapoints for a year

# %%
file2 = "Norfolk.csv"
df_results = pd.read_csv(file2)

new_columns = df_results.columns[0].split("output_test")[1].split("_sensors.csv")[:-1]
df_results = pd.DataFrame(df_results.values.reshape(int(len(df_results.values)/reporting_datapoints),reporting_datapoints)).T
df_results.columns = new_columns
df_results
# Out:
#          11ce6ed7-03e1-426d-adbb-04a8011d767f  \
# 0    lighting_setback_error_early_termination
# 1            hvac_setback_error_delayed_onset
# 2            hvac_setback_error_delayed_onset
# 3            hvac_setback_error_delayed_onset
# 4            hvac_setback_error_delayed_onset
# ..                                        ...
# 360          hvac_setback_error_delayed_onset
# 361          hvac_setback_error_delayed_onset
# 362          hvac_setback_error_delayed_onset
# 363          hvac_setback_error_delayed_onset
# 364          hvac_setback_error_delayed_onset
#
#          3f9c38dd-02c2-47bf-945c-ae401017ccae  \
# 0    lighting_setback_error_early_termination
# 1                condenser_fouling_in_chiller
# 2    lighting_setback_error_early_termination
# 3    lighting_setback_error_early_termination
# 4    lighting_setback_error_early_termination
# ..                                        ...
# 360  lighting_setback_error_early_termination
# 361  lighting_setback_error_early_termination
# 362  lighting_setback_error_early_termination
# 363  lighting_setback_error_early_termination
# 364  lighting_setback_error_early_termination
#
#          655d9c80-14e6-4f80-a6f1-711b2ff0f9e5  \
# 0    lighting_setback_error_early_termination
# 1                             thermostat_bias
# 2                             thermostat_bias
# 3                             thermostat_bias
# 4                             thermostat_bias
# ..                                        ...
# 360                           thermostat_bias
# 361                           thermostat_bias
# 362                           thermostat_bias
# 363                           thermostat_bias
# 364                           thermostat_bias
#
#             6961fa68-66ce-42fd-9161-0fcb37bfa0bd  \
# 0       lighting_setback_error_early_termination
# 1                   condenser_fouling_in_chiller
# 2    nonstandard_refrigerant_charging_in_chiller
# 3                   condenser_fouling_in_chiller
# 4    nonstandard_refrigerant_charging_in_chiller
# ..                                           ...
# 360        presence_of_noncondensable_in_chiller
# 361        presence_of_noncondensable_in_chiller
# 362  nonstandard_refrigerant_charging_in_chiller
# 363        presence_of_noncondensable_in_chiller
# 364  nonstandard_refrigerant_charging_in_chiller
#
#          843c0271-ddb1-4cf3-972c-b9f0524d4fb8  \
# 0    lighting_setback_error_early_termination
# 1                condenser_fouling_in_chiller
# 2                condenser_fouling_in_chiller
# 3                condenser_fouling_in_chiller
# 4                condenser_fouling_in_chiller
# ..                                        ...
# 360              condenser_fouling_in_chiller
# 361              condenser_fouling_in_chiller
# 362              condenser_fouling_in_chiller
# 363              condenser_fouling_in_chiller
# 364              condenser_fouling_in_chiller
#
#          912040e6-d307-410e-8321-e71e49c0c615  \
# 0    lighting_setback_error_early_termination
# 1                    supply_air_duct_leakages
# 2                    supply_air_duct_leakages
# 3                    supply_air_duct_leakages
# 4                    supply_air_duct_leakages
# ..                                        ...
# 360                  supply_air_duct_leakages
# 361                  supply_air_duct_leakages
# 362                  supply_air_duct_leakages
# 363                  supply_air_duct_leakages
# 364                  supply_air_duct_leakages
#
#          a5566c06-690a-47dc-8a6e-9f695eae8ea0  \
# 0    lighting_setback_error_early_termination
# 1                      excessive_infiltration
# 2             improperly_sized_equipment_wshp
# 3             improperly_sized_equipment_wshp
# 4             improperly_sized_equipment_wshp
# ..                                        ...
# 360           improperly_sized_equipment_wshp
# 361              condenser_fouling_in_chiller
# 362           improperly_sized_equipment_wshp
# 363              condenser_fouling_in_chiller
# 364                    excessive_infiltration
#
#          e0baeb44-227c-4374-9c14-6693f3f6c9b1  \
# 0    lighting_setback_error_early_termination
# 1                      excessive_infiltration
# 2             improperly_sized_equipment_wshp
# 3                condenser_fouling_in_chiller
# 4                condenser_fouling_in_chiller
# ..                                        ...
# 360                    excessive_infiltration
# 361                    excessive_infiltration
# 362                    excessive_infiltration
# 363                    excessive_infiltration
# 364                    excessive_infiltration
#
#             e1598de2-3062-4f40-b343-05defbd8c32c
# 0       lighting_setback_error_early_termination
# 1                   condenser_fouling_in_chiller
# 2    nonstandard_refrigerant_charging_in_chiller
# 3                   condenser_fouling_in_chiller
# 4                   condenser_fouling_in_chiller
# ..                                           ...
# 360  nonstandard_refrigerant_charging_in_chiller
# 361  nonstandard_refrigerant_charging_in_chiller
# 362  nonstandard_refrigerant_charging_in_chiller
# 363              improperly_sized_equipment_wshp
# 364  nonstandard_refrigerant_charging_in_chiller
#
# [365 rows x 9 columns]

# %%
df_diagnosis = []

for bldgid in df_results.columns:
    
    print()

    temp = pd.DataFrame(df_results[bldgid].groupby(df_results[bldgid]).count())
    temp.columns = ['counts']
    temp = temp.sort_values(by='counts', ascending=False)
    diagnose_fault = temp.iloc[0:1].index[0]
    diagnose_pcnt = (temp.iloc[0:1].counts.values[0])/(temp.sum().values[0])
    groundtruth = df_meta.loc[df_meta.id==bldgid, :].fault_type.values[0]
    
    df_diagnosis.append([bldgid, groundtruth, diagnose_fault, diagnose_pcnt])
    
    
    print(f"Ground Truth = {groundtruth} || Diagnosis = {diagnose_fault}")
    
df_diagnosis = pd.DataFrame(df_diagnosis)
df_diagnosis.columns = ['id','GroundTruth','DiagnosedFault','ConfidenceRatio']
df_diagnosis = df_diagnosis.sort_values(by='ConfidenceRatio',ascending=False)
df_diagnosis
# Out:
# Ground Truth = hvac_setback_error_delayed_onset || Diagnosis = hvac_setback_error_delayed_onset
#
# Ground Truth = lighting_setback_error_early_termination || Diagnosis = lighting_setback_error_early_termination
#
# Ground Truth = thermostat_bias || Diagnosis = thermostat_bias
#
# Ground Truth = presence_of_noncondensable_in_chiller || Diagnosis = presence_of_noncondensable_in_chiller
#
# Ground Truth = condenser_fouling_in_chiller || Diagnosis = condenser_fouling_in_chiller
#
# Ground Truth = supply_air_duct_leakages || Diagnosis = supply_air_duct_leakages
#
# Ground Truth = improperly_sized_equipment_wshp || Diagnosis = improperly_sized_equipment_wshp
#
# Ground Truth = excessive_infiltration || Diagnosis = excessive_infiltration
#
# Ground Truth = nonstandard_refrigerant_charging_in_chiller || Diagnosis = nonstandard_refrigerant_charging_in_chiller
#                                      id  \
# 2  655d9c80-14e6-4f80-a6f1-711b2ff0f9e5
# 5  912040e6-d307-410e-8321-e71e49c0c615
# 0  11ce6ed7-03e1-426d-adbb-04a8011d767f
# 1  3f9c38dd-02c2-47bf-945c-ae401017ccae
# 4  843c0271-ddb1-4cf3-972c-b9f0524d4fb8
# 7  e0baeb44-227c-4374-9c14-6693f3f6c9b1
# 6  a5566c06-690a-47dc-8a6e-9f695eae8ea0
# 8  e1598de2-3062-4f40-b343-05defbd8c32c
# 3  6961fa68-66ce-42fd-9161-0fcb37bfa0bd
#
#                                    GroundTruth  \
# 2                              thermostat_bias
# 5                     supply_air_duct_leakages
# 0             hvac_setback_error_delayed_onset
# 1     lighting_setback_error_early_termination
# 4                 condenser_fouling_in_chiller
# 7                       excessive_infiltration
# 6              improperly_sized_equipment_wshp
# 8  nonstandard_refrigerant_charging_in_chiller
# 3        presence_of_noncondensable_in_chiller
#
#                                 DiagnosedFault  ConfidenceRatio
# 2                              thermostat_bias         0.997260
# 5                     supply_air_duct_leakages         0.991781
# 0             hvac_setback_error_delayed_onset         0.964384
# 1     lighting_setback_error_early_termination         0.926027
# 4                 condenser_fouling_in_chiller         0.789041
# 7                       excessive_infiltration         0.605479
# 6              improperly_sized_equipment_wshp         0.600000
# 8  nonstandard_refrigerant_charging_in_chiller         0.487671
# 3        presence_of_noncondensable_in_chiller         0.400000

# %%
df_diagnosis.to_csv("./output.csv")

# %% [markdown]
# Log file processing

# %%
logfile = "log.csv"
logdf = pd.read_csv(logfile)
logdf
# Out:
#     randomseed  weather labeling methodology feature selection methodology  \
# 0          953  Norfolk               Simple                      Embedded
# 1         1163  Norfolk               Simple                      Embedded
# 2         3004  Norfolk               Simple                      Embedded
# 3         5493  Norfolk               Simple                      Embedded
# 4         3313  Norfolk               Simple                      Embedded
# 5         7861  Norfolk               Simple                      Embedded
# 6         1492  Norfolk               Simple                      Embedded
# 7         6871  Norfolk               Simple                      Embedded
# 8         1027  Norfolk               Simple                      Embedded
# 9         3629  Norfolk               Simple                      Embedded
# 10        4687  Norfolk               Simple                      Embedded
# 11        5440  Norfolk               Simple                      Embedded
# 12         988  Norfolk               Simple                      Embedded
# 13        8710  Norfolk               Simple                      Embedded
# 14        1514  Norfolk               Simple                      Embedded
# 15         308  Norfolk               Simple                      Embedded
# 16        5055  Norfolk               Simple                      Embedded
# 17        8494  Norfolk               Simple                      Embedded
# 18        9650  Norfolk               Simple                      Embedded
# 19        7359  Norfolk               Simple                      Embedded
# 20        8791  Norfolk               Simple                      Embedded
# 21        6461  Norfolk               Simple                      Embedded
# 22        5003  Norfolk               Simple                      Embedded
# 23        4252  Norfolk               Simple                      Embedded
# 24        5847  Norfolk               Simple                      Embedded
# 25        8489  Norfolk               Simple                      Embedded
# 26        9834  Norfolk               Simple                      Embedded
# 27        8205  Norfolk               Simple                      Embedded
# 28        3811  Norfolk               Simple                      Embedded
#
#     number of trees  aggregate n runs  training CDDR  testing CDDR
# 0                 4               144       0.904110      0.111111
# 1                 4               144       0.903349      0.108067
# 2                 4               144       0.915906      0.114155
# 3                 4               144       0.905251      0.108067
# 4                 4               144       0.916286      0.109589
# 5                20               144       0.994673      0.112633
# 6                20               144       0.996575      0.111111
# 7                20               144       0.993912      0.109589
# 8                20               144       0.993151      0.109589
# 9                20               144       0.993531      0.109589
# 10              100               144       0.997336      0.109589
# 11              100               144       0.997336      0.108067
# 12              200               144       0.997336      0.111111
# 13              200               144       0.997336      0.108067
# 14              400               144       0.997336      0.108067
# 15              400               144       0.997336      0.111111
# 16              400               144       0.997336      0.111111
# 17              400               144       0.997336      0.108067
# 18              400               144       0.997336      0.112633
# 19              400               144       1.000000      0.114155
# 20              400               144       1.000000      0.112633
# 21              400               144       1.000000      0.109589
# 22              400               144       0.997717      0.109589
# 23              400               144       0.997336      0.111111
# 24                4               144       0.906012      0.108067
# 25                4               144       0.906773      0.106545
# 26                4               144       0.918569      0.108067
# 27                4               144       0.908676      0.108067
# 28                4               144       0.912861      0.111111

# %%
treedf = logdf[(logdf['number of trees']==400) | (logdf['number of trees']==4)]
treedf
# Out:
#     randomseed  weather labeling methodology feature selection methodology  \
# 0          953  Norfolk               Simple                      Embedded
# 1         1163  Norfolk               Simple                      Embedded
# 2         3004  Norfolk               Simple                      Embedded
# 3         5493  Norfolk               Simple                      Embedded
# 4         3313  Norfolk               Simple                      Embedded
# 14        1514  Norfolk               Simple                      Embedded
# 15         308  Norfolk               Simple                      Embedded
# 16        5055  Norfolk               Simple                      Embedded
# 17        8494  Norfolk               Simple                      Embedded
# 18        9650  Norfolk               Simple                      Embedded
# 19        7359  Norfolk               Simple                      Embedded
# 20        8791  Norfolk               Simple                      Embedded
# 21        6461  Norfolk               Simple                      Embedded
# 22        5003  Norfolk               Simple                      Embedded
# 23        4252  Norfolk               Simple                      Embedded
# 24        5847  Norfolk               Simple                      Embedded
# 25        8489  Norfolk               Simple                      Embedded
# 26        9834  Norfolk               Simple                      Embedded
# 27        8205  Norfolk               Simple                      Embedded
# 28        3811  Norfolk               Simple                      Embedded
#
#     number of trees  aggregate n runs  training CDDR  testing CDDR
# 0                 4               144       0.904110      0.111111
# 1                 4               144       0.903349      0.108067
# 2                 4               144       0.915906      0.114155
# 3                 4               144       0.905251      0.108067
# 4                 4               144       0.916286      0.109589
# 14              400               144       0.997336      0.108067
# 15              400               144       0.997336      0.111111
# 16              400               144       0.997336      0.111111
# 17              400               144       0.997336      0.108067
# 18              400               144       0.997336      0.112633
# 19              400               144       1.000000      0.114155
# 20              400               144       1.000000      0.112633
# 21              400               144       1.000000      0.109589
# 22              400               144       0.997717      0.109589
# 23              400               144       0.997336      0.111111
# 24                4               144       0.906012      0.108067
# 25                4               144       0.906773      0.106545
# 26                4               144       0.918569      0.108067
# 27                4               144       0.908676      0.108067
# 28                4               144       0.912861      0.111111

# %%
import matplotlib.pyplot as plt
medianprops = dict(linestyle='-', linewidth=2, color='k')
#boxprops = dict(linestyle='-', linewidth=2, color='r')
boxplot = treedf.boxplot(column=['training CDDR', 'testing CDDR'], 
                        by='number of trees', 
                        grid=False, 
                        return_type='axes',
                        medianprops=medianprops)
plt.suptitle('')
plt.show()
